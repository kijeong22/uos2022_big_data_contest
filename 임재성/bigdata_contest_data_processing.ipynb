# %% [markdown]
# 환경 세팅

# %%
# 한글 깨질 때 사용
import matplotlib 
from matplotlib import font_manager, rc
import platform

if platform.system() == "Windows":
  font_name = font_manager.FontProperties(fname = "c:/Windows/Fonts/malgun.ttf").get_names()
  rc('font', family = font_name)
else:
  rc('font', family = 'AppleGothic')

  matplotlib.rcParams['axes.unicode_minus'] = False

# %%
# !pip install xlrd==1.2.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 103 kB 9.6 MB/s
# ...
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 1.1.0
#     Uninstalling xlrd-1.1.0:
#       Successfully uninstalled xlrd-1.1.0
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd

# %% [markdown]
# 월별 교통사고.xls 전처리

# %%
# local_file_path : 로컬 파일 경로 
local_file_path = '../data/월별 교통사고.xls' 
colab_file_path =  '/content/gdrive/My Drive/빅데이터경진대회/월별 교통사고.xls' 
file_path = colab_file_path

df_raw = pd.read_excel(file_path)

# %%
# 개인형이동수단만 추출
df_pm_raw = df_raw.iloc[58:61,2:]

# %%
# 열 이름 renaming
df_pm_raw.columns = ["유형",
                 "2017년", "2017년 1월", "2017년 2월", "2017년 3월", "2017년 4월",
                 "2017년 5월", "2017년 6월", "2017년 7월", "2017년 8월", 
                 "2017년 9월", "2017년 10월", "2017년 11월", "2017년 12월", 
                 "2018년", "2018년 1월", "2018년 2월", "2018년 3월", "2018년 4월",
                 "2018년 5월", "2018년 6월", "2018년 7월", "2018년 8월", 
                 "2018년 9월", "2018년 10월", "2018년 11월", "2018년 12월",
                 "2019년", "2019년 1월", "2019년 2월", "2019년 3월", "2019년 4월",
                 "2019년 5월", "2019년 6월", "2019년 7월", "2019년 8월", 
                 "2019년 9월", "2019년 10월", "2019년 11월", "2019년 12월",
                 "2020년", "2020년 1월", "2020년 2월", "2020년 3월", "2020년 4월",
                 "2020년 5월", "2020년 6월", "2020년 7월", "2020년 8월", 
                 "2020년 9월", "2020년 10월", "2020년 11월", "2020년 12월",
                 "2021년", "2021년 1월", "2021년 2월", "2021년 3월", "2021년 4월",
                 "2021년 5월", "2021년 6월", "2021년 7월", "2021년 8월", 
                 "2021년 9월", "2021년 10월", "2021년 11월", "2021년 12월"]

# %%
#연도별, 월별 혼합 데이터
df_pm_month_year = df_pm_raw.reset_index(drop = True).replace('-', 0)
df_pm_month_year
# Out:
#      유형  2017년  2017년 1월  2017년 2월  2017년 3월  2017년 4월  2017년 5월  2017년 6월  \
# 0  사고건수    117         0         2         4         4        15         7
# 1  사망자수      4         0         0         0         0         0         1
# 2  부상자수    124         0         2         4         5        16         8
#
#    2017년 7월  2017년 8월  ...  2021년 3월  2021년 4월  2021년 5월  2021년 6월  2021년 7월  \
# 0        13        17  ...       133       173       166       167       186
# 1         1         1  ...         1         0         0         2         2
# 2        14        17  ...       143       201       186       179       199
#
#    2021년 8월  2021년 9월  2021년 10월  2021년 11월  2021년 12월
# 0       181       184        174        152        113
# 1         1         2          4          2          2
# 2       197       206        189        164        121
#
# [3 rows x 66 columns]

# %%
#월별 데이터 추출
df_pm_month = df_pm_month_year.loc[[0, 1, 2],
                ["유형","2017년 1월", "2017년 2월", "2017년 3월", "2017년 4월",
                 "2017년 5월", "2017년 6월", "2017년 7월", "2017년 8월", 
                 "2017년 9월", "2017년 10월", "2017년 11월", "2017년 12월", 
                 "2018년 1월", "2018년 2월", "2018년 3월", "2018년 4월",
                 "2018년 5월", "2018년 6월", "2018년 7월", "2018년 8월", 
                 "2018년 9월", "2018년 10월", "2018년 11월", "2018년 12월",
                 "2019년 1월", "2019년 2월", "2019년 3월", "2019년 4월",
                 "2019년 5월", "2019년 6월", "2019년 7월", "2019년 8월", 
                 "2019년 9월", "2019년 10월", "2019년 11월", "2019년 12월",
                 "2020년 1월", "2020년 2월", "2020년 3월", "2020년 4월",
                 "2020년 5월", "2020년 6월", "2020년 7월", "2020년 8월", 
                 "2020년 9월", "2020년 10월", "2020년 11월", "2020년 12월",
                 "2021년 1월", "2021년 2월", "2021년 3월", "2021년 4월",
                 "2021년 5월", "2021년 6월", "2021년 7월", "2021년 8월", 
                 "2021년 9월", "2021년 10월", "2021년 11월", "2021년 12월"]]
df_pm_month
# Out:
#      유형  2017년 1월  2017년 2월  2017년 3월  2017년 4월  2017년 5월  2017년 6월  2017년 7월  \
# 0  사고건수         0         2         4         4        15         7        13
# 1  사망자수         0         0         0         0         0         1         1
# 2  부상자수         0         2         4         5        16         8        14
#
#    2017년 8월  2017년 9월  ...  2021년 3월  2021년 4월  2021년 5월  2021년 6월  2021년 7월  \
# 0        17        15  ...       133       173       166       167       186
# 1         1         0  ...         1         0         0         2         2
# 2        17        16  ...       143       201       186       179       199
#
#    2021년 8월  2021년 9월  2021년 10월  2021년 11월  2021년 12월
# 0       181       184        174        152        113
# 1         1         2          4          2          2
# 2       197       206        189        164        121
#
# [3 rows x 61 columns]

# %%
#연도별 데이터 추출
df_year_pm = df_pm_month_year.loc[[0, 1, 2], ["유형","2017년", "2018년", "2019년", "2020년", "2021년"]]
df_year_pm
# Out:
#      유형  2017년  2018년  2019년  2020년  2021년
# 0  사고건수    117    225    447    897   1735
# 1  사망자수      4      4      8     10     19
# 2  부상자수    124    238    473    985   1901

# %% [markdown]
# 시각화 연습
# (전처리 과정 바꿔서 실행 안됨)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rc
# %matplotlib inline
plt.rc('font', family='NanumBarunGothic') # clolab 에서 한글 사용 
plt.rcParams['axes.unicode_minus'] = False

# %%
#글자 사이즈 조정
SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)

# %%
plt.figure(figsize = (4,7))
df_year_pm["사고건수"].plot.bar(color = 'red')
plt.xticks(rotation = 45)

# %%
df_year_pm["사망자수"].plot.bar(color = 'red')
plt.xticks(rotation = 45)
# Out:
# (array([0, 1, 2, 3, 4]), <a list of 5 Text major ticklabel objects>)

# %%
plt.figure(figsize = (4,7))
df_year_pm["부상자수"].plot.bar(color = 'red')
plt.xticks(rotation = 45)
# Out:
# (array([0, 1, 2, 3, 4]), <a list of 5 Text major ticklabel objects>)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#seaborn 연습
df_year1_pm = df_year_pm.reset_index()

# %%
df_year1_pm.columns = ['Year', '사고건수', '사망자수', '부상자수']
df_year1_pm
# Out:
#     Year  사고건수 사망자수  부상자수
# 0  2017년   117    4   124
# 1  2018년   225    4   238
# 2  2019년   447    8   473
# 3  2020년   897   10   985
# 4  2021년  1735   19  1901

# %%
df_year1_pm_melt = df_year1_pm.melt(id_vars = 'Year') 
df_year1_pm_melt
# Out:
#      Year variable value
# 0   2017년     사고건수   117
# 1   2018년     사고건수   225
# 2   2019년     사고건수   447
# 3   2020년     사고건수   897
# 4   2021년     사고건수  1735
# 5   2017년     사망자수     4
# 6   2018년     사망자수     4
# 7   2019년     사망자수     8
# 8   2020년     사망자수    10
# 9   2021년     사망자수    19
# 10  2017년     부상자수   124
# 11  2018년     부상자수   238
# 12  2019년     부상자수   473
# 13  2020년     부상자수   985
# 14  2021년     부상자수  1901

# %%
sns.barplot(x = "variable", y = "value", hue = "Year", data = df_year1_pm_melt)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44256 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44148 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47581 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %% [markdown]
# 시간대별 교통사고.xls 전처리

# %%
# local_file_path : 로컬 파일 경로 
local_file_path = '../data/시간대별 교통사고.xls' 
colab_file_path =  '/content/gdrive/My Drive/빅데이터경진대회/시간대별 교통사고.xls' 
file_path = colab_file_path

df1_raw = pd.read_excel(file_path)

# %%
df1_pm_raw = df1_raw.iloc[58:61, 2:]

# %%
df1_pm_raw.columns = [ "유형",
                 "2017년", "2017년 0~2시", "2017년 2~4시", "2017년 4~6시", "2017년 6~8시",
                 "2017년 8~10시", "2017년 10~12시", "2017년 12~14시", "2017년 14~16시", 
                 "2017년 16~18시", "2017년 18~20시", "2017년 20~22시","2017년 22~24시", 
                 "2018년", "2018년 0~2시", "2018년 2~4시", "2018년 4~6시", "2018년 6~8시",
                 "2018년 8~10시", "2018년 10~12시", "2018년 12~14시", "2018년 14~16시", 
                 "2018년 16~18시", "2018년 18~20시", "2018년 20~22시","2018년 22~24시",
                 "2019년", "2019년 0~2시", "2019년 2~4시", "2019년 4~6시", "2019년 6~8시",
                 "2019년 8~10시", "2019년 10~12시", "2019년 12~14시", "2019년 14~16시", 
                 "2019년 16~18시", "2019년 18~20시", "2019년 20~22시","2019년 22~24시",
                 "2020년", "2020년 0~2시", "2020년 2~4시", "2020년 4~6시", "2020년 6~8시",
                 "2020년 8~10시", "2020년 10~12시", "2020년 12~14시", "2020년 14~16시", 
                 "2020년 16~18시", "2020년 18~20시", "2020년 20~22시","2020년 22~24시",
                 "2021년", "2021년 0~2시", "2021년 2~4시", "2021년 4~6시", "2021년 6~8시",
                 "2021년 8~10시", "2021년 10~12시", "2021년 12~14시", "2021년 14~16시", 
                 "2021년 16~18시", "2021년 18~20시", "2021년 20~22시","2021년 22~24시"]

# %%
df1_pm_raw
# Out:
#       유형 2017년 2017년 0~2시 2017년 2~4시 2017년 4~6시 2017년 6~8시 2017년 8~10시  \
# 58  사고건수   117          6          8          1          7          20
# 59  사망자수     4          1          1          0          0           0
# 60  부상자수   124          5          7          1          7          20
#
#    2017년 10~12시 2017년 12~14시 2017년 14~16시  ... 2021년 4~6시 2021년 6~8시  \
# 58           10            6           10  ...         28         52
# 59            0            0            1  ...          2          1
# 60           11            6            9  ...         30         57
#
#    2021년 8~10시 2021년 10~12시 2021년 12~14시 2021년 14~16시 2021년 16~18시  \
# 58         135          122          142          185          250
# 59           2            1            0            3            0
# 60         141          136          160          195          275
#
#    2021년 18~20시 2021년 20~22시 2021년 22~24시
# 58          247          204          232
# 59            0            5            3
# ...

# %%
df_pm_time = df1_pm_raw.reset_index(drop = True).replace('-', 0)
df_pm_time
# Out:
#      유형 2017년 2017년 0~2시 2017년 2~4시 2017년 4~6시 2017년 6~8시 2017년 8~10시  \
# 0  사고건수   117          6          8          1          7          20
# 1  사망자수     4          1          1          0          0           0
# 2  부상자수   124          5          7          1          7          20
#
#   2017년 10~12시 2017년 12~14시 2017년 14~16시  ... 2021년 4~6시 2021년 6~8시  \
# 0           10            6           10  ...         28         52
# 1            0            0            1  ...          2          1
# 2           11            6            9  ...         30         57
#
#   2021년 8~10시 2021년 10~12시 2021년 12~14시 2021년 14~16시 2021년 16~18시  \
# 0         135          122          142          185          250
# 1           2            1            0            3            0
# 2         141          136          160          195          275
#
#   2021년 18~20시 2021년 20~22시 2021년 22~24시
# 0          247          204          232
# 1            0            5            3
# ...

# %% [markdown]
# 시도별 교통사고.xls 전처리

# %%
# local_file_path : 로컬 파일 경로 
local_file_path = '../data/시도별 교통사고.xls' 
colab_file_path =  '/content/gdrive/My Drive/빅데이터경진대회/시도별 교통사고.xls' 
file_path = colab_file_path

df2_raw = pd.read_excel(file_path)

# %%
df2_raw = df2_raw[['가해운전자 차종별 교통사고', 'Unnamed: 1','Unnamed: 21','Unnamed: 50', 'Unnamed: 79', 'Unnamed: 108', 'Unnamed: 137']].iloc[4:58,:].reset_index(drop = True).replace('-', 0)

# %%
#시도별 사고건수 사망자수 부상자수 혼합데이터
df2_raw.columns = ["시도", "유형", "2017년", "2018년", "2019년", "2020년", "2021년"]
df_pm_region = df2_raw
df_pm_region
# Out:
#     시도    유형  2017년  2018년  2019년  2020년  2021년
# 0   합계  사고건수    117    225    447    897   1735
# 1   합계  사망자수      4      4      8     10     19
# 2   합계  부상자수    124    238    473    985   1901
# 3   서울  사고건수     29     50    134    387    445
# 4   서울  사망자수      1      0      1      1      1
# 5   서울  부상자수     30     56    139    420    489
# 6   부산  사고건수      8     13     14     34     46
# 7   부산  사망자수      0      0      0      0      1
# 8   부산  부상자수      9     13     14     37     48
# 9   대구  사고건수      9     12     25     43    104
# 10  대구  사망자수      0      0      0      0      0
# 11  대구  부상자수     11     13     27     46    116
# 12  인천  사고건수      4      9     19     27     60
# 13  인천  사망자수      0      0      0      2      1
# 14  인천  부상자수      4      9     22     29     63
# 15  광주  사고건수      3     15     18     38    100
# 16  광주  사망자수      0      0      0      1      0
# 17  광주  부상자수      4     16     21     41    116
# 18  대전  사고건수      8     10     34     29     45
# ...

# %%
#시도별 사고건수 데이터
df_pm_region_acci = df_pm_region[df_pm_region["유형"] == "사고건수"].reset_index(drop = True)
df_pm_region_acci
# Out:
#     시도    유형  2017년  2018년  2019년  2020년  2021년
# 0   합계  사고건수    117    225    447    897   1735
# 1   서울  사고건수     29     50    134    387    445
# 2   부산  사고건수      8     13     14     34     46
# 3   대구  사고건수      9     12     25     43    104
# 4   인천  사고건수      4      9     19     27     60
# 5   광주  사고건수      3     15     18     38    100
# 6   대전  사고건수      8     10     34     29     45
# 7   울산  사고건수      0      7      9      5     21
# 8   세종  사고건수      0      0      1      5     11
# 9   경기  사고건수     27     59    122    223    536
# 10  강원  사고건수      5      0      6     13     26
# 11  충북  사고건수      7     17     19     22     71
# 12  충남  사고건수      3     10     13     17     38
# 13  전북  사고건수      2      2      7      9     27
# 14  전남  사고건수      0      2      8      6     47
# 15  경북  사고건수      6     12      7     16     74
# 16  경남  사고건수      3      4      7     16     53
# 17  제주  사고건수      3      3      4      7     31

# %%
#시도별 사망자수 데이터
df_pm_region_death = df_pm_region[df_pm_region["유형"] == "사망자수"].reset_index(drop = True)
df_pm_region_death
# Out:
#     시도    유형  2017년  2018년  2019년  2020년  2021년
# 0   합계  사망자수      4      4      8     10     19
# 1   서울  사망자수      1      0      1      1      1
# 2   부산  사망자수      0      0      0      0      1
# 3   대구  사망자수      0      0      0      0      0
# 4   인천  사망자수      0      0      0      2      1
# 5   광주  사망자수      0      0      0      1      0
# 6   대전  사망자수      0      0      1      0      1
# 7   울산  사망자수      0      0      0      0      1
# 8   세종  사망자수      0      0      0      0      0
# 9   경기  사망자수      2      3      3      4      5
# 10  강원  사망자수      0      0      0      0      0
# 11  충북  사망자수      0      0      1      1      2
# 12  충남  사망자수      0      0      0      0      2
# 13  전북  사망자수      1      1      1      0      1
# 14  전남  사망자수      0      0      0      0      1
# 15  경북  사망자수      0      0      1      0      2
# 16  경남  사망자수      0      0      0      0      1
# 17  제주  사망자수      0      0      0      1      0

# %%
#시도별 부상자수 데이터
df_pm_region_injury = df_pm_region[df_pm_region["유형"] == "부상자수"].reset_index(drop = True)
df_pm_region_injury
# Out:
#     시도    유형  2017년  2018년  2019년  2020년  2021년
# 0   합계  부상자수    124    238    473    985   1901
# 1   서울  부상자수     30     56    139    420    489
# 2   부산  부상자수      9     13     14     37     48
# 3   대구  부상자수     11     13     27     46    116
# 4   인천  부상자수      4      9     22     29     63
# 5   광주  부상자수      4     16     21     41    116
# 6   대전  부상자수     10     11     38     33     52
# 7   울산  부상자수      0      7      9      5     28
# 8   세종  부상자수      0      0      1      7     11
# 9   경기  부상자수     26     58    132    247    587
# 10  강원  부상자수      7      0      6     15     28
# 11  충북  부상자수      7     19     19     26     77
# 12  충남  부상자수      3     11     13     20     40
# 13  전북  부상자수      1      1      6      9     30
# 14  전남  부상자수      0      2      8      6     52
# 15  경북  부상자수      6     14      7     20     75
# 16  경남  부상자수      3      5      7     18     58
# 17  제주  부상자수      3      3      4      6     31

# %% [markdown]
# 사고유형별 교통사고.xls 전처리

# %%
# local_file_path : 로컬 파일 경로 
local_file_path = '../data/사고유형별 교통사고.xls' 
colab_file_path =  '/content/gdrive/My Drive/빅데이터경진대회/사고유형별 교통사고.xls' 
file_path = colab_file_path

df3_raw = pd.read_excel(file_path)

# %%
df3_raw = df3_raw[['사고유형중구분', '기준년도', '2017년.19', '2018년.19', '2019년.19', '2020년.19', '2021년.19']].iloc[2:56,:]

# %%
df3_raw.columns = ['사고유형', '유형', '2017년', '2018년', '2019년', '2020년', '2021년']

# %%
#사고유형별 사고건수 사망자수 부상자수 혼합데이터
df_pm_type = df3_raw.reset_index(drop = True).replace('-', 0)
df_pm_type
# Out:
#           사고유형    유형  2017년  2018년  2019년  2020년  2021년
# 0           합계  부상자수    124    238    473    985   1901
# 1          횡단중  사고건수      6     12     29     46    105
# 2          횡단중  사망자수      0      1      0      0      0
# 3          횡단중  부상자수      7     13     29     52    111
# 4        차도통행중  사고건수      3      7      7     17     30
# 5        차도통행중  사망자수      0      0      0      0      0
# 6        차도통행중  부상자수      4      8      8     18     32
# 7   길가장자리구역통행중  사고건수      1      4      2     10     17
# 8   길가장자리구역통행중  사망자수      0      0      0      0      0
# 9   길가장자리구역통행중  부상자수      1      4      2     11     17
# 10       보도통행중  사고건수      7     10     34     87    226
# 11       보도통행중  사망자수      0      0      0      0      0
# 12       보도통행중  부상자수      8     10     35     89    233
# 13    기타(차대사람)  사고건수     16     28     58    144    285
# 14    기타(차대사람)  사망자수      0      0      0      0      0
# 15    기타(차대사람)  부상자수     18     29     63    150    301
# ...

# %% [markdown]
# 대중교통 이용량.xlsx

# %%
# local_file_path : 로컬 파일 경로 
local_file_path = '../data/대중교통 교통사고.xls' 
colab_file_path =  '/content/gdrive/My Drive/빅데이터경진대회/대중교통 교통사고.xls' 
file_path = colab_file_path

df4_raw = pd.read_excel(file_path)

# %%
df4_raw = df4_raw.iloc[6:24,:]

# %%
df4_raw.columns = ['지역', '2017_일반_이용인원', '2017_일반_비율', '2017_어린이_이용인원', '2017_어린이_비율',
           '2017_청소년_이용인원', '2017_청소년_비율', '2017_기타_이용인원', '2017_기타_비율',
           '2018_일반_이용인원', '2018_일반_비율', '2018_어린이_이용인원', '2018_어린이_비율',
           '2018_청소년_이용인원', '2018_청소년_비율', '2018_기타_이용인원', '2018_기타_비율',
           '2019_일반_이용인원', '2019_일반_비율', '2019_어린이_이용인원', '2019_어린이_비율',
           '2019_청소년_이용인원', '2019_청소년_비율', '2019_기타_이용인원', '2019_기타_비율',
           '2020_일반_이용인원', '2020_일반_비율', '2020_어린이_이용인원', '2020_어린이_비율',
           '2020_청소년_이용인원', '2020_청소년_비율', '2020_기타_이용인원', '2020_기타_비율',
           '2021_일반_이용인원', '2021_일반_비율', '2021_어린이_이용인원', '2021_어린이_비율',
           '2021_청소년_이용인원', '2021_청소년_비율', '2021_기타_이용인원', '2021_기타_비율']

# %%
#대중교통 이용량
df_pt = df4_raw.reset_index(drop = True).replace('- ', 0)
df_pt
# Out:
#          지역 2017_일반_이용인원 2017_일반_비율 2017_어린이_이용인원 2017_어린이_비율 2017_청소년_이용인원  \
# 0        전체   9,684,492    84.56 %       109,851      0.96 %     1,002,726
# 1     서울특별시   3,711,168    83.89 %        36,098      0.82 %       259,128
# 2     부산광역시     873,876    91.27 %         8,098      0.85 %        75,528
# 3     대구광역시     468,819    85.62 %         5,548      1.01 %        73,150
# 4     인천광역시     634,790    81.86 %         7,271      0.94 %        74,764
# 5     광주광역시     204,102    82.98 %         2,624      1.07 %        35,991
# 6     대전광역시     231,496    85.08 %         2,139      0.79 %        29,237
# 7     울산광역시     131,211    86.04 %         2,559      1.68 %        18,519
# 8   세종특별자치시      20,341    89.70 %           189      0.83 %         2,147
# 9       경기도   2,518,216    84.46 %        28,941      0.97 %       269,178
# 10      강원도      66,733    77.84 %         2,373      2.77 %        15,773
# ...

# %% [markdown]
# 기상상태별 교통사고

# %%
# local_file_path : 로컬 파일 경로 
local_file_path = '../data/기상상태별 교통사고.xls' 
colab_file_path =  '/content/gdrive/My Drive/빅데이터경진대회/기상상태별 교통사고.xls' 
file_path = colab_file_path

df5_raw = pd.read_excel(file_path)

# %%
df5_raw = df5_raw[['기상상태', '기준년도', '2017년.19', '2018년.19', '2019년.19', '2020년.19', '2021년.19']].iloc[2:26,:]

# %%
#기상상태별 사고건수 사망자수 부상자수 혼합데이터
df5_raw.columns = ['기상상태', '유형', '2017년', '2018년','2019년','2020년','2021년']
df_pm_weather = df5_raw.reset_index(drop = True).replace('-', 0)
df_pm_weather
# Out:
#    기상상태    유형  2017년  2018년  2019년  2020년  2021년
# 0    합계  사고건수    117    225    447    897   1735
# 1    합계  사망자수      4      4      8     10     19
# 2    합계  부상자수    124    238    473    985   1901
# 3    맑음  사고건수    114    212    428    828   1619
# 4    맑음  사망자수      3      3      7     10     18
# 5    맑음  부상자수    121    224    455    911   1777
# 6    흐림  사고건수      0      5      8     29     46
# 7    흐림  사망자수      0      0      1      0      0
# 8    흐림  부상자수      0      6      7     31     51
# 9     비  사고건수      2      8      8     26     43
# 10    비  사망자수      0      1      0      0      1
# 11    비  부상자수      3      8      8     28     46
# 12   안개  사고건수      0      0      0      0      0
# 13   안개  사망자수      0      0      0      0      0
# 14   안개  부상자수      0      0      0      0      0
# 15    눈  사고건수      0      0      0      1      1
# 16    눈  사망자수      0      0      0      0      0
# 17    눈  부상자수      0      0      0      1      1
# ...

# %%
#기상상태별 사고건수
df_pm_weather_acci = df_pm_weather[df_pm_weather["유형"] == "사고건수"].reset_index(drop = True)
df_pm_weather_acci
# Out:
#   기상상태    유형  2017년  2018년  2019년  2020년  2021년
# 0   합계  사고건수    117    225    447    897   1735
# 1   맑음  사고건수    114    212    428    828   1619
# 2   흐림  사고건수      0      5      8     29     46
# 3    비  사고건수      2      8      8     26     43
# 4   안개  사고건수      0      0      0      0      0
# 5    눈  사고건수      0      0      0      1      1
# 6   기타  사고건수      1      0      3     13     26
# 7  미분류  사고건수      0      0      0      0      0

# %%
#기상상태별 사망자수
df_pm_weather_death = df_pm_weather[df_pm_weather["유형"] == "사망자수"].reset_index(drop = True)
df_pm_weather_death
# Out:
#   기상상태    유형  2017년  2018년  2019년  2020년  2021년
# 0   합계  사망자수      4      4      8     10     19
# 1   맑음  사망자수      3      3      7     10     18
# 2   흐림  사망자수      0      0      1      0      0
# 3    비  사망자수      0      1      0      0      1
# 4   안개  사망자수      0      0      0      0      0
# 5    눈  사망자수      0      0      0      0      0
# 6   기타  사망자수      1      0      0      0      0
# 7  미분류  사망자수      0      0      0      0      0

# %%
#기상상태별 부상자수
df_pm_weather_injury = df_pm_weather[df_pm_weather["유형"] == "부상자수"].reset_index(drop = True)
df_pm_weather_injury
# Out:
#   기상상태    유형  2017년  2018년  2019년  2020년  2021년
# 0   합계  부상자수    124    238    473    985   1901
# 1   맑음  부상자수    121    224    455    911   1777
# 2   흐림  부상자수      0      6      7     31     51
# 3    비  부상자수      3      8      8     28     46
# 4   안개  부상자수      0      0      0      0      0
# 5    눈  부상자수      0      0      0      1      1
# 6   기타  부상자수      0      0      3     14     26
# 7  미분류  부상자수      0      0      0      0      0
